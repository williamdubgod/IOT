# %%
import pandas as pd

# %%
df = pd.read_csv('/content/diamonds.csv')
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.shape
# Out:
# (53940, 11)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['price']]
# Out:
#        price
# 0        326
# 1        326
# 2        327
# 3        334
# 4        335
# ...      ...
# 53935   2757
# 53936   2757
# 53937   2757
# 53938   2757
# 53939   2757
#
# [53940 rows x 1 columns]

# %%
#Calcular a média da população

media = df[['price']].mean()
media
# Out:
# price    3932.799722
# dtype: float64

# %%
#Calcular a médiana da população

media = df[['price']].median()
media
# Out:
# price    2401.0
# dtype: float64

# %%
#Calcular o desvio padrão da população

desvio_padrao = df[['price']].std()
desvio_padrao
# Out:
# price    3989.439738
# dtype: float64

# %% [markdown]
# # Geração de amostras

# %%
#Primeira amostra

a1 = df.iloc[0:3000,:] #linhas e colunas
a1
# Out:
#       Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0              1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1              2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2              3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3              4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4              5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...          ...    ...        ...   ...     ...    ...    ...    ...   ...
# 2995        2996   0.90       Good     G     SI2   63.8   59.0   3303  6.02
# 2996        2997   0.90       Good     I     VS2   63.7   61.0   3303  6.06
# 2997        2998   0.90       Good     G     SI2   63.4   59.0   3303  6.04
# 2998        2999   0.90  Very Good     G     SI2   59.2   57.0   3303  6.30
# 2999        3000   0.90       Good     G     SI2   63.8   56.0   3303  6.13
#
#          y     z
# 0     3.98  2.43
# 1     3.84  2.31
# ...

# %%
#Media coluna price para a1

a1[['price']].mean()
# Out:
# price    2739.121
# dtype: float64

# %%
#Mediana coluna price para a1

a1[['price']].median()
# Out:
# price    2963.0
# dtype: float64

# %%
#Desvio padrão coluna price

a1[['price']].std()
# Out:
# price    793.568209
# dtype: float64

# %% [markdown]
# #Segunda amostra

# %%
#Segunda amostra

a2 = df.iloc[3000:6000, :]
a2
# Out:
#       Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 3000        3001   0.70      Ideal     G    VVS1   60.7   57.0   3303  5.73
# 3001        3002   0.77      Ideal     E     VS2   61.0   56.0   3303  5.91
# 3002        3003   0.81      Ideal     F     SI2   62.1   56.0   3303  5.95
# 3003        3004   0.71      Ideal     E     VS2   62.1   55.0   3304  5.72
# 3004        3005   0.71      Ideal     E     VS2   62.0   56.0   3304  5.72
# ...          ...    ...        ...   ...     ...    ...    ...    ...   ...
# 5995        5996   1.03    Premium     J     VS1   61.8   58.0   3957  6.51
# 5996        5997   0.91    Premium     D     SI2   61.2   58.0   3958  6.21
# 5997        5998   1.06  Very Good     H     SI2   62.6   58.0   3958  6.46
# 5998        5999   0.90      Ideal     E     SI2   61.9   54.0   3958  6.23
# 5999        6000   1.01    Premium     H     SI2   62.8   61.0   3959  6.33
#
#          y     z
# 3000  5.76  3.49
# 3001  5.96  3.62
# ...

# %%
#Media coluna price para a2

a2[['price']].mean()
# Out:
# price    3324.448333
# dtype: float64

# %%
#Mediana coluna price para a2

a2[['price']].median()
# Out:
# price    3601.0
# dtype: float64

# %%
#Media coluna price para a2

a2[['price']].std()
# Out:
# price    940.914622
# dtype: float64

# %% [markdown]
# #Terceira amostra (usando componente de aleatoriedade)

# %%
a3 = df.sample(3000, random_state=0)
a3
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 10176       10177   1.10      Ideal     H     SI2   62.0   55.0   4733  6.61
# 16083       16084   1.29      Ideal     H     SI1   62.6   56.0   6424  6.96
# 13420       13421   1.20    Premium     I     SI1   61.1   58.0   5510  6.88
# 20407       20408   1.50      Ideal     F     SI1   60.9   56.0   8770  7.43
# 8909         8910   0.90  Very Good     F     VS2   61.7   57.0   4493  6.17
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 36013       36014   0.39    Premium     J    VVS1   61.8   56.0    921  4.71
# 48293       48294   0.54      Ideal     G     VS1   61.0   57.0   1957  5.25
# 3114         3115   0.91       Good     H     SI1   63.8   56.0   3323  6.09
# 32497       32498   0.43    Premium     D     SI1   62.4   60.0    796  4.79
# 21463       21464   1.52    Premium     D     SI2   60.6   62.0   9561  7.42
#
#           y     z
# 10176  6.65  4.11
# ...

# %%
a3[['price']].mean()
# Out:
# price    3934.155333
# dtype: float64

# %%
a3[['price']].median()
# Out:
# price    2409.0
# dtype: float64

# %%
a3[['price']].std()
# Out:
# price    3948.251524
# dtype: float64
